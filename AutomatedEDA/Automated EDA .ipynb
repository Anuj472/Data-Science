# %%
#Automated EDA Technique
#!pip install pandas_profiling

# %%
#import pandas_profiling

# %%
import seaborn as sns
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#from pandas_profiling import ProfileReport

# %%
#profile=ProfileReport(df,explorative=True,dark_mode=True)

# %%
#profile.to_file('output.html')

# %%
# !pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\anujm\anaconda3\anaconda\lib\site-packages (2.7.1)
# Requirement already satisfied: seaborn in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.11.2)
# Requirement already satisfied: cycler in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.10.0)
# Requirement already satisfied: openpyxl in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (3.0.9)
# Requirement already satisfied: strsimpy in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: itsdangerous in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: scipy in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.7.1)
# Requirement already satisfied: statsmodels in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.12.2)
# Requirement already satisfied: flask-ngrok in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: kaleido in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: et-xmlfile in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: Flask-Compress in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.12)
# Requirement already satisfied: numpy in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.21.6)
# Requirement already satisfied: dash-daq in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: dash-colorscales in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: xlrd in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: dash-bootstrap-components in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.2.1)
# Requirement already satisfied: squarify in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: networkx in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (2.6.3)
# Requirement already satisfied: six in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: Flask in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.1.2)
# Requirement already satisfied: requests in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (2.28.1)
# Requirement already satisfied: dash>=2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (2.6.1)
# Requirement already satisfied: xarray in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (2022.6.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (5.9.0)
# Requirement already satisfied: pandas in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.4.3)
# Requirement already satisfied: matplotlib in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (3.4.3)
# Requirement already satisfied: future>=0.14.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.18.2)
# Requirement already satisfied: certifi in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (2021.10.8)
# Requirement already satisfied: scikit-learn in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (1.1.2)
# Requirement already satisfied: missingno<=0.4.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (0.4.2)
# Requirement already satisfied: lz4 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dtale) (4.0.2)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dash>=2.0.0->dtale) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from Flask->dtale) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\anujm\appdata\roaming\python\python39\site-packages (from Flask->dtale) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from Flask->dtale) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from Jinja2>=2.10.1->Flask->dtale) (2.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from plotly>=5.0.0->dtale) (8.0.1)
# Requirement already satisfied: brotli in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pandas->dtale) (2021.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anujm\appdata\roaming\python\python39\site-packages (from requests->dtale) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from requests->dtale) (1.26.7)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from scikit-learn->dtale) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from scikit-learn->dtale) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from statsmodels->dtale) (0.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from xarray->dtale) (21.0)

# %%
pip install -U --pre pycaret
# Out:
# Collecting pycaret
#   Using cached pycaret-3.0.0rc3-py3-none-any.whl (544 kB)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (1.1.2)
# Requirement already satisfied: scipy<1.9.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (1.7.1)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (0.12.2)
# Collecting sktime~=0.11.4
#   Using cached sktime-0.11.4-py3-none-any.whl (6.7 MB)
# Collecting imbalanced-learn>=0.8.1
#   Using cached imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (3.4.3)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (7.6.5)
# Collecting schemdraw>=0.14
#   Using cached schemdraw-0.15-py3-none-any.whl (106 kB)
# Collecting psutil>=5.9.0
#   Using cached psutil-5.9.1-cp39-cp39-win_amd64.whl (245 kB)
# Collecting category-encoders>=2.4.0
#   Using cached category_encoders-2.5.0-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: jinja2>=1.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: pandas<1.5.0,>=1.3.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (1.4.3)
# Collecting scikit-plot>=0.3.7
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting numba~=0.55.0
#   Using cached numba-0.55.2-cp39-cp39-win_amd64.whl (2.4 MB)
# Collecting plotly-resampler>=0.7.2.2
#   Using cached plotly_resampler-0.8.0rc12-cp39-cp39-win_amd64.whl
# Requirement already satisfied: numpy~=1.21 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (1.21.6)
# Collecting yellowbrick>=1.4
#   Using cached yellowbrick-1.4-py3-none-any.whl (274 kB)
# Requirement already satisfied: requests>=2.27.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (2.28.1)
# Collecting tbats>=1.1.0
#   Using cached tbats-1.1.0-py3-none-any.whl (43 kB)
# Collecting lightgbm>=3.0.0
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: joblib>=1.1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (7.29.0)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (4.62.3)
# Collecting pyod>=0.9.8
#   Using cached pyod-1.0.4-py3-none-any.whl
# Collecting pmdarima>=1.8.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
#   Using cached pmdarima-1.8.5-cp39-cp39-win_amd64.whl (601 kB)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: pickleshare in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: colorama in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.4)
# Requirement already satisfied: backcall in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: pygments in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (2.10.0)
# Requirement already satisfied: decorator in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (58.0.4)
# Requirement already satisfied: matplotlib-inline in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (228)
# Requirement already satisfied: wheel in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.3.0->pycaret) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.4)
# Requirement already satisfied: six in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from cycler>=0.10->matplotlib>=3.3.0->pycaret) (1.16.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Using cached llvmlite-0.38.1-cp39-cp39-win_amd64.whl (23.2 MB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pandas<1.5.0,>=1.3.0->pycaret) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Collecting trace-updater>=0.0.8
#   Using cached trace_updater-0.0.8-py3-none-any.whl (185 kB)
# Collecting Flask-Cors<4.0.0,>=3.0.10
#   Using cached Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting jupyter-dash>=0.4.2
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.6.1)
# Collecting orjson<4.0.0,>=3.7.7
#   Using cached orjson-3.7.11-cp39-none-win_amd64.whl (199 kB)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.12)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.1.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (5.0.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.2)
# Requirement already satisfied: click>=5.1 in c:\users\anujm\appdata\roaming\python\python39\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (7.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.5.1)
# Collecting ansi2html
#   Using cached ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: retrying in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.3.3)
# Requirement already satisfied: urllib3 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pmdarima>=1.8.0->pycaret) (1.26.7)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pmdarima>=1.8.0->pycaret) (0.29.24)
# Requirement already satisfied: wcwidth in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anujm\appdata\roaming\python\python39\site-packages (from requests>=2.27.1->pycaret) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->pycaret) (2021.10.8)
# Collecting deprecated>=1.2.13
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from deprecated>=1.2.13->sktime~=0.11.4->pycaret) (1.12.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.11.0)
# Requirement already satisfied: nbconvert in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.20)
# Requirement already satisfied: brotli in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from flask-compress->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.0.9)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.3)
# Requirement already satisfied: bleach in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: testpath in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.0)
# Requirement already satisfied: async-generator in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.10)
# Requirement already satisfied: webencodings in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: packaging in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.0)
# Installing collected packages: llvmlite, ansi2html, trace-updater, pmdarima, orjson, numba, jupyter-dash, Flask-Cors, deprecated, yellowbrick, tbats, sktime, scikit-plot, schemdraw, pyod, psutil, plotly-resampler, lightgbm, imbalanced-learn, category-encoders, pycaret
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.37.0

# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
pip install markupsafe==2.0.1
# Out:
# Requirement already satisfied: markupsafe==2.0.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtale

# %%
dtale.show(df)
# Out:
# C:\Users\anujm\anaconda3\anaconda\lib\site-packages\dtale\views.py:725: FutureWarning:
#
# ['embarked', 'class', 'deck', 'embark_town'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://anuj:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.4-py3-none-any.whl (15.1 MB)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from sweetviz) (4.62.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from sweetviz) (1.4.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from sweetviz) (1.7.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from sweetviz) (1.21.6)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from sweetviz) (3.4.3)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: six in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from cycler>=0.10->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.3)
# Requirement already satisfied: colorama in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.4)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.9.0 sweetviz-2.1.4

# %%
import sweetviz as sv
report=sv.analyze(df)
report.show_html('newreport.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report newreport.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# !pip install dataprep
# Out:
# Collecting dataprep
#   Using cached dataprep-0.4.5-py3-none-any.whl (9.9 MB)
# Collecting jsonpath-ng<2.0,>=1.5
#   Using cached jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting pydot<2.0.0,>=1.4.2
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting aiohttp<4.0,>=3.6
#   Using cached aiohttp-3.8.1-cp39-cp39-win_amd64.whl (554 kB)
# Collecting jinja2<3.1,>=3.0
#   Using cached Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting rapidfuzz<3.0.0,>=2.1.2
#   Using cached rapidfuzz-2.4.3-cp39-cp39-win_amd64.whl (1.2 MB)
# Requirement already satisfied: bokeh<3,>=2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dataprep) (2.4.1)
# Collecting nltk<4.0.0,>=3.6.7
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dataprep) (4.62.3)
# Requirement already satisfied: regex<2022.0.0,>=2021.8.3 in c:\users\anujm\appdata\roaming\python\python39\site-packages (from dataprep) (2021.9.30)
# Requirement already satisfied: pydantic<2.0,>=1.6 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dataprep) (1.9.0)
# Collecting scipy<2.0,>=1.8
#   Using cached scipy-1.9.0-cp39-cp39-win_amd64.whl (38.6 MB)
# Collecting flask_cors<4.0.0,>=3.0.10
#   Using cached Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting wordcloud<2.0,>=1.8
#   Using cached wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dataprep) (1.4.3)
# Collecting varname<0.9.0,>=0.8.1
#   Using cached varname-0.8.3-py3-none-any.whl (21 kB)
# Collecting python-stdnum<2.0,>=1.16
#   Using cached python_stdnum-1.17-py2.py3-none-any.whl (943 kB)
# Collecting python-crfsuite==0.9.8
#   Using cached python_crfsuite-0.9.8-cp39-cp39-win_amd64.whl (158 kB)
# Collecting sqlalchemy==1.3.24
#   Using cached SQLAlchemy-1.3.24-cp39-cp39-win_amd64.whl (1.2 MB)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dataprep) (7.6.5)
# Collecting dask[array,dataframe,delayed]>=2022.3.0
#   Using cached dask-2022.8.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: numpy<2.0,>=1.21 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dataprep) (1.21.6)
# Collecting metaphone<0.7,>=0.6
#   Using cached Metaphone-0.6-py3-none-any.whl
# Collecting flask<3,>=2
#   Using cached Flask-2.2.2-py3-none-any.whl (101 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.0.4)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.1-cp39-cp39-win_amd64.whl (34 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.8.1-cp39-cp39-win_amd64.whl (56 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (21.2.0)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.2-cp39-cp39-win_amd64.whl (28 kB)
# Requirement already satisfied: tornado>=5.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (8.4.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\anujm\appdata\roaming\python\python39\site-packages (from bokeh<3,>=2->dataprep) (3.10.0.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\anujm\appdata\roaming\python\python39\site-packages (from bokeh<3,>=2->dataprep) (5.4.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (21.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.0.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.11.1)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2021.10.1)
# Collecting click>=8.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from flask<3,>=2->dataprep) (4.8.1)
# Collecting Werkzeug>=2.2.2
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from flask<3,>=2->dataprep) (2.0.1)
# Requirement already satisfied: colorama in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from click>=8.0->flask<3,>=2->dataprep) (0.4.4)
# Requirement already satisfied: Six in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from importlib-metadata>=3.6.0->flask<3,>=2->dataprep) (3.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (7.29.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.4.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.4.1)
# Requirement already satisfied: backcall in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (58.0.4)
# Requirement already satisfied: pygments in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: decorator in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jinja2<3.1,>=3.0->dataprep) (2.1.1)
# Requirement already satisfied: ply in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: pyzmq>=13 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: joblib in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from packaging>=16.8->bokeh<3,>=2->dataprep) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2021.3)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# aws-sam-cli 1.50.0 requires click~=7.1, but you have click 8.1.3 which is incompatible.
# aws-sam-cli 1.50.0 requires Flask~=1.1.2, but you have flask 2.2.2 which is incompatible.
# aws-sam-cli 1.50.0 requires MarkupSafe==2.0.1, but you have markupsafe 2.1.1 which is incompatible.
# aws-sam-cli 1.50.0 requires requests==2.25.1, but you have requests 2.28.1 which is incompatible.
# distributed 2021.10.0 requires dask==2021.10.0, but you have dask 2022.8.0 which is incompatible.
# Requirement already satisfied: locket in c:\users\anujm\anaconda3\anaconda\lib\site-packages\locket-0.2.1-py3.9.egg (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.2.1)
# Requirement already satisfied: wcwidth in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Collecting jarowinkler<2.0.0,>=1.2.0
#   Using cached jarowinkler-1.2.0-cp39-cp39-win_amd64.whl (61 kB)
# Collecting pure_eval<1.0.0
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting asttokens<3.0.0,>=2.0.0
#   Using cached asttokens-2.0.7-py2.py3-none-any.whl (23 kB)
# Collecting executing<0.9.0,>=0.8.3
#   Using cached executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.4.5)
# Requirement already satisfied: prometheus-client in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (20.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.7)
# Requirement already satisfied: matplotlib in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.4.3)
# Requirement already satisfied: idna>=2.0 in c:\users\anujm\appdata\roaming\python\python39\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (2.10)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.20)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.10.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: testpath in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.3)
# Requirement already satisfied: bleach in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: async-generator in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Installing collected packages: jinja2, Werkzeug, multidict, frozenlist, click, yarl, pure-eval, jarowinkler, flask, executing, dask, async-timeout, asttokens, aiosignal, wordcloud, varname, sqlalchemy, scipy, rapidfuzz, python-stdnum, python-crfsuite, pydot, nltk, metaphone, jsonpath-ng, flask-cors, aiohttp, dataprep
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.2
#     Uninstalling Werkzeug-2.0.2:
#       Successfully uninstalled Werkzeug-2.0.2
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.2
#     Uninstalling Flask-1.1.2:
#       Successfully uninstalled Flask-1.1.2
#   Attempting uninstall: dask
#     Found existing installation: dask 2021.10.0
#     Uninstalling dask-2021.10.0:
#       Successfully uninstalled dask-2021.10.0
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.22
#     Uninstalling SQLAlchemy-1.4.22:
#       Successfully uninstalled SQLAlchemy-1.4.22
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Uninstalling scipy-1.7.1:
#       Successfully uninstalled scipy-1.7.1
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.6.5
#     Uninstalling nltk-3.6.5:
#       Successfully uninstalled nltk-3.6.5
# Successfully installed Werkzeug-2.2.2 aiohttp-3.8.1 aiosignal-1.2.0 asttokens-2.0.7 async-timeout-4.0.2 click-8.1.3 dask-2022.8.0 dataprep-0.4.5 executing-0.8.3 flask-2.2.2 flask-cors-3.0.10 frozenlist-1.3.1 jarowinkler-1.2.0 jinja2-3.0.3 jsonpath-ng-1.5.3 metaphone-0.6 multidict-6.0.2 nltk-3.7 pure-eval-0.2.2 pydot-1.4.2 python-crfsuite-0.9.8 python-stdnum-1.17 rapidfuzz-2.4.3 scipy-1.9.0 sqlalchemy-1.3.24 varname-0.8.3 wordcloud-1.8.2.2 yarl-1.8.1

# %%
from dataprep.eda import create_report
create_report(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8904/3092447544.py in <module>
# ----> 1 from dataprep.eda import create_report
#       2 create_report(df)
#
# ~\anaconda3\anaconda\lib\site-packages\dataprep\eda\__init__.py in <module>
#       6
#       7 from ..utils import is_notebook
# ----> 8 from .correlation import compute_correlation, plot_correlation, render_correlation
#       9 from .create_report import create_report
#      10 from .create_db_report import create_db_report
#
# ~\anaconda3\anaconda\lib\site-packages\dataprep\eda\correlation\__init__.py in <module>
#       5 from typing import Any, Dict, List, Optional, Tuple, Union
#       6
# ----> 7 import dask.dataframe as dd
#       8 import pandas as pd
#       9
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\__init__.py in <module>
#       2     import dask.dataframe._pyarrow_compat
#       3     from dask.base import compute
# ----> 4     from dask.dataframe import backends, dispatch, rolling
#       5     from dask.dataframe.core import (
#       6         DataFrame,
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\backends.py in <module>
#      18 from dask.array.dispatch import percentile_lookup
#      19 from dask.array.percentile import _percentile
# ---> 20 from dask.dataframe.core import DataFrame, Index, Scalar, Series, _Frame
#      21 from dask.dataframe.dispatch import (
#      22     categorical_dtype_dispatch,
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\core.py in <module>
#      33 from dask.blockwise import Blockwise, BlockwiseDep, BlockwiseDepDict, blockwise
#      34 from dask.context import globalmethod
# ---> 35 from dask.dataframe import methods
#      36 from dask.dataframe._compat import PANDAS_GT_140, PANDAS_GT_150
#      37 from dask.dataframe.accessor import CachedAccessor, DatetimeAccessor, StringAccessor
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\methods.py in <module>
#      20     union_categoricals,
#      21 )
# ---> 22 from dask.dataframe.utils import is_dataframe_like, is_index_like, is_series_like
#      23
#      24 # cuDF may try to import old dispatch functions
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\utils.py in <module>
#      17 from dask.base import get_scheduler, is_dask_collection
#      18 from dask.core import get_deps
# ---> 19 from dask.dataframe import (  # noqa: F401 register pandas extension types
#      20     _dtypes,
#      21     methods,
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\_dtypes.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 from dask.dataframe.extensions import make_array_nonempty, make_scalar
#       4
#       5
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\extensions.py in <module>
#       4 See :ref:`extensionarrays` for more.
#       5 """
# ----> 6 from dask.dataframe.accessor import (
#       7     register_dataframe_accessor,
#       8     register_index_accessor,
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\accessor.py in <module>
#     188
#     189
# --> 190 class StringAccessor(Accessor):
#     191     """Accessor object for string properties of the Series values.
#     192
#
# ~\anaconda3\anaconda\lib\site-packages\dask\dataframe\accessor.py in StringAccessor()
#     273         return self._function_map(method, pat=pat, n=n, expand=expand, meta=meta)
#     274
# --> 275     @derived_from(
#     276         pd.core.strings.StringMethods,
#     277         inconsistencies="``expand=True`` with unknown ``n`` will raise a ``NotImplementedError``",
#
# TypeError: derived_from() got an unexpected keyword argument 'inconsistencies'

# %%
# !pip install lux
# Out:
# Requirement already satisfied: lux in c:\users\anujm\anaconda3\anaconda\lib\site-packages (0.5.1)
# Requirement already satisfied: lux-widget in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux) (0.1.11)
# Requirement already satisfied: lux-api in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux) (0.5.1)
# Requirement already satisfied: autopep8>=1.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (1.5.7)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (5.9.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (3.4.3)
# Requirement already satisfied: sh in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (1.14.2)
# Requirement already satisfied: altair>=4.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (4.2.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (1.1.2)
# Requirement already satisfied: scipy>=1.3.3 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (1.9.0)
# Requirement already satisfied: iso3166 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (2.1.1)
# Requirement already satisfied: pandas in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (1.4.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-api->lux) (1.21.6)
# Requirement already satisfied: entrypoints in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from altair>=4.0.0->lux-api->lux) (0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from altair>=4.0.0->lux-api->lux) (3.2.0)
# Requirement already satisfied: jinja2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from altair>=4.0.0->lux-api->lux) (3.0.3)
# Requirement already satisfied: toolz in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from altair>=4.0.0->lux-api->lux) (0.11.1)
# Requirement already satisfied: toml in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from autopep8>=1.5->lux-api->lux) (0.10.2)
# Requirement already satisfied: pycodestyle>=2.7.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from autopep8>=1.5->lux-api->lux) (2.7.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (58.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (21.2.0)
# Requirement already satisfied: notebook>=4.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-widget->lux) (6.4.5)
# Requirement already satisfied: ipywidgets>=7.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from lux-widget->lux) (7.6.5)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (5.1.3)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (7.29.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (5.1.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (3.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.18.0)
# Requirement already satisfied: pickleshare in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.7.5)
# Requirement already satisfied: pygments in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (2.10.0)
# Requirement already satisfied: colorama in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.4.4)
# Requirement already satisfied: decorator in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (3.0.20)
# Requirement already satisfied: backcall in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (228)
# Requirement already satisfied: cycler>=0.10 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (8.4.0)
# Requirement already satisfied: argon2-cffi in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (1.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from pandas->lux-api->lux) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.5)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from scikit-learn>=0.22->lux-api->lux) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from scikit-learn>=0.22->lux-api->lux) (2.2.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.0.0->lux-widget->lux) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget->lux) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0.0->lux-widget->lux) (2.20)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from jinja2->altair>=4.0.0->lux-api->lux) (2.1.1)
# Requirement already satisfied: bleach in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (4.0.0)
# Requirement already satisfied: defusedxml in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (1.4.3)
# Requirement already satisfied: testpath in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->lux-widget->lux) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->lux-widget->lux) (1.10)
# Requirement already satisfied: packaging in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget->lux) (21.0)
# Requirement already satisfied: webencodings in c:\users\anujm\anaconda3\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.1)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
import lux
lux.logger=True

# %%
# !pip install pandas_visual_analysis
VisualAnalysis(df)
